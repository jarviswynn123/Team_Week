# %%
import pandas as pd
import matplotlib.pyplot as plt

music_topics_df = pd.read_csv("./data/music_topics_cleaned.csv", header=0)
print(music_topics_df.head())
print(music_topics_df.tail())
# Out:
#             artist_name            track_name  release_date genre  \
# 0                mukesh  mohabbat bhi jhoothi          1950   pop
# 1         frankie laine             i believe          1950   pop
# 2           johnnie ray                   cry          1950   pop
# 3           pérez prado              patricia          1950   pop
# 4  giorgos papadopoulos    apopse eida oneiro          1950   pop
#
#                                               lyrics  violence  world/life  \
# 0  hold time feel break feel untrue convince spea...  0.063746    0.000598
# 1  believe drop rain fall grow believe darkest ni...  0.096777    0.443435
# 2  sweetheart send letter goodbye secret feel bet...  0.002770    0.002770
# 3  kiss lips want stroll charm mambo chacha merin...  0.001548    0.001548
# 4  till darling till matter know till dream live ...  0.001350    0.417772
#
#    night/time  romantic   obscene   sadness       topic
# 0    0.000598  0.017104  0.000598  0.380299     sadness
# 1    0.001284  0.001284  0.001284  0.001284  world/life
# 2    0.002770  0.158564  0.002770  0.002770       music
# 3    0.001548  0.411536  0.001548  0.225889    romantic
# 4    0.001350  0.463430  0.001350  0.068800    romantic
#       artist_name                     track_name  release_date    genre  \
# 27755     mack 10                10 million ways          2019  hip hop
# 27756      m.o.p.  ante up (robbin hoodz theory)          2019  hip hop
# 27757        nine                  whutcha want?          2019  hip hop
# 27758  will smith                         switch          2019  hip hop
# 27759       jeezy                         r.i.p.          2019  hip hop
#
#                                                   lyrics  violence  \
# 27755  cause fuck leave scar tick tock clock come kno...  0.001350
# 27756  minks things chain ring braclets yap fame come...  0.001284
# 27757  get ban get ban stick crack relax plan attack ...  0.154302
# 27758  check check yeah yeah hear thing call switch g...  0.001196
# 27759  remix killer alive remix thriller trap bitch s...  0.075202
#
#        world/life  night/time  romantic   obscene   sadness    topic
# 27755    0.001350    0.001350  0.001350  0.391651  0.065664  obscene
# 27756    0.035338    0.001284  0.066324  0.318910  0.001284  obscene
# 27757    0.168988    0.001504  0.035401  0.356685  0.001504  obscene
# 27758    0.001196    0.001196  0.001196  0.492434  0.001196  obscene
# 27759    0.001012    0.001012  0.001012  0.754444  0.001012  obscene

# %%
#parse the data out by decades 
#1950s
music_topics_fifties = music_topics_df.loc[music_topics_df.release_date.isin([1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959])]
print(music_topics_fifties.shape)

#1960s
music_topics_sixties = music_topics_df.loc[music_topics_df.release_date.isin([1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969])]
print(music_topics_sixties.shape)

#1970s
music_topics_seventies = music_topics_df.loc[music_topics_df.release_date.isin([1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979])]
print(music_topics_seventies.shape)

#1980s
music_topics_eighties = music_topics_df.loc[music_topics_df.release_date.isin([1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989])]
print(music_topics_eighties.shape)

#1990s
music_topics_nineties = music_topics_df.loc[music_topics_df.release_date.isin([1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999])]
print(music_topics_nineties.shape)

#2000s
music_topics_2000s = music_topics_df.loc[music_topics_df.release_date.isin([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009])]
print(music_topics_2000s.shape)

#2010s
music_topics_2010s = music_topics_df.loc[music_topics_df.release_date.isin([2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019])]
print(music_topics_2010s.shape)
# Out:
# (1443, 12)
# (3324, 12)
# (3826, 12)
# (4581, 12)
# (4372, 12)
# (4678, 12)
# (5536, 12)

# %%
#parsed the data into pop songs for each decade

#1950s pop
music_topics_50s_pop = music_topics_fifties.loc[music_topics_fifties.genre == 'pop']
print(music_topics_50s_pop.shape)

#1960s pop
music_topics_60s_pop = music_topics_sixties.loc[music_topics_sixties.genre == 'pop']
print(music_topics_60s_pop.shape)

#1970s pop
music_topics_70s_pop = music_topics_seventies.loc[music_topics_seventies.genre == 'pop']
print(music_topics_70s_pop.shape)

#1980s pop
music_topics_80s_pop = music_topics_eighties.loc[music_topics_eighties.genre == 'pop']
print(music_topics_80s_pop.shape)

#1990s pop
music_topics_90s_pop = music_topics_nineties.loc[music_topics_nineties.genre == 'pop']
print(music_topics_90s_pop.shape)

#2000s pop
music_topics_00s_pop = music_topics_2000s.loc[music_topics_2000s.genre == 'pop']
print(music_topics_00s_pop.shape)

#2010s pop
music_topics_10s_pop = music_topics_2010s.loc[music_topics_2010s.genre == 'pop']
print(music_topics_10s_pop.shape)
# Out:
# (323, 12)
# (1073, 12)
# (1023, 12)
# (1165, 12)
# (1056, 12)
# (1098, 12)
# (1164, 12)

# %%
music_topics_fifties.groupby(by="topic").count()
# Out:
#             artist_name  track_name  release_date  genre  lyrics  violence  \
# topic
# music               229         229           229    229     229       229
# night/time           99          99            99     99      99        99
# obscene             145         145           145    145     145       145
# romantic            249         249           249    249     249       249
# sadness             344         344           344    344     344       344
# violence            136         136           136    136     136       136
# world/life          241         241           241    241     241       241
#
#             world/life  night/time  romantic  obscene  sadness
# topic
# music              229         229       229      229      229
# night/time          99          99        99       99       99
# obscene            145         145       145      145      145
# romantic           249         249       249      249      249
# sadness            344         344       344      344      344
# violence           136         136       136      136      136
# world/life         241         241       241      241      241

# %%
#use unique topic values as the labels
labels = list(music_topics_df.topic.unique())
#alphabetize label list
labels.sort()
print(labels)

fifties_count = [229, 99, 145, 249, 344, 136, 241]

fig_50s, ax_50s = plt.subplots()

ax_50s.pie(fifties_count, labels= labels, autopct="%1.1f%%")

ax_50s.axis('equal')

plt.title('Topic of songs in 1950s')

plt.style.use('dark_background')

plt.legend(labels, bbox_to_anchor=(1,1), loc='best')

plt.show()
# Out:
# ['music', 'night/time', 'obscene', 'romantic', 'sadness', 'violence', 'world/life']

# %%
music_topics_50s_pop.groupby(by="topic").count()
# Out:
#             artist_name  track_name  release_date  genre  lyrics  violence  \
# topic
# music                42          42            42     42      42        42
# night/time           25          25            25     25      25        25
# obscene              25          25            25     25      25        25
# romantic             58          58            58     58      58        58
# sadness              90          90            90     90      90        90
# violence             35          35            35     35      35        35
# world/life           48          48            48     48      48        48
#
#             world/life  night/time  romantic  obscene  sadness
# topic
# music               42          42        42       42       42
# night/time          25          25        25       25       25
# obscene             25          25        25       25       25
# romantic            58          58        58       58       58
# sadness             90          90        90       90       90
# violence            35          35        35       35       35
# world/life          48          48        48       48       48

# %%
count_50s_pop = [42, 25, 25, 58, 90, 35, 48]
fig_50s_pop, ax_50s_pop = plt.subplots()

ax_50s_pop.pie(count_50s_pop, labels= labels, autopct="%1.1f%%")

ax_50s_pop.axis('equal')

plt.title('Topics of Pop Songs in 1950s')

plt.style.use('dark_background')

plt.legend(labels, bbox_to_anchor=(1,1), loc='best')

plt.show()

# %%
music_topics_sixties.groupby(by="topic").count()
# Out:
#             artist_name  track_name  release_date  genre  lyrics  violence  \
# topic
# music               431         431           431    431     431       431
# night/time          245         245           245    245     245       245
# obscene             317         317           317    317     317       317
# romantic            351         351           351    351     351       351
# sadness             898         898           898    898     898       898
# violence            390         390           390    390     390       390
# world/life          692         692           692    692     692       692
#
#             world/life  night/time  romantic  obscene  sadness
# topic
# music              431         431       431      431      431
# night/time         245         245       245      245      245
# obscene            317         317       317      317      317
# romantic           351         351       351      351      351
# sadness            898         898       898      898      898
# violence           390         390       390      390      390
# world/life         692         692       692      692      692

# %%
sixties_count = [431, 245, 317, 351, 898, 390, 692]
fig_60s, ax_60s = plt.subplots()

ax_60s.pie(sixties_count, labels= labels, autopct="%1.1f%%")

ax_60s.axis('equal')

plt.title('Topics of Songs in 1960s')

plt.style.use('dark_background')

plt.legend(labels, bbox_to_anchor=(1,1), loc='best')

plt.show()

# %%
music_topics_60s_pop.groupby(by="topic").count()
# Out:
#             artist_name  track_name  release_date  genre  lyrics  violence  \
# topic
# music               133         133           133    133     133       133
# night/time           64          64            64     64      64        64
# obscene              86          86            86     86      86        86
# romantic            137         137           137    137     137       137
# sadness             330         330           330    330     330       330
# violence            112         112           112    112     112       112
# world/life          211         211           211    211     211       211
#
#             world/life  night/time  romantic  obscene  sadness
# topic
# music              133         133       133      133      133
# night/time          64          64        64       64       64
# obscene             86          86        86       86       86
# romantic           137         137       137      137      137
# sadness            330         330       330      330      330
# violence           112         112       112      112      112
# world/life         211         211       211      211      211

# %%
count_60s_pop = [133, 64, 86, 137, 330, 112, 211]
fig_60s_pop, ax_60s_pop = plt.subplots()

ax_60s_pop.pie(count_60s_pop, labels= labels, autopct="%1.1f%%")

ax_60s_pop.axis('equal')

plt.title('Topics of Pop Songs in 1960s')

plt.style.use('dark_background')

plt.legend(labels, bbox_to_anchor=(1,1), loc='best')

plt.show()

# %%
music_topics_seventies.groupby(by="topic").count()
# Out:
#             artist_name  track_name  release_date  genre  lyrics  violence  \
# topic
# music               461         461           461    461     461       461
# night/time          304         304           304    304     304       304
# obscene             420         420           420    420     420       420
# romantic            227         227           227    227     227       227
# sadness             774         774           774    774     774       774
# violence            701         701           701    701     701       701
# world/life          939         939           939    939     939       939
#
#             world/life  night/time  romantic  obscene  sadness
# topic
# music              461         461       461      461      461
# night/time         304         304       304      304      304
# obscene            420         420       420      420      420
# romantic           227         227       227      227      227
# sadness            774         774       774      774      774
# violence           701         701       701      701      701
# world/life         939         939       939      939      939

# %%
seventies_count = [461, 304, 420, 227, 774, 701, 939]
fig_70s, ax_70s = plt.subplots()

ax_70s.pie(seventies_count, labels= labels, autopct="%1.1f%%")

ax_70s.axis('equal')

plt.title('Topics of Songs in 1970s')

plt.style.use('dark_background')

plt.legend(labels, bbox_to_anchor=(1,1), loc='best')

plt.show()

# %%
music_topics_70s_pop.groupby(by="topic").count()
# Out:
#             artist_name  track_name  release_date  genre  lyrics  violence  \
# topic
# music               129         129           129    129     129       129
# night/time           82          82            82     82      82        82
# obscene              79          79            79     79      79        79
# romantic             72          72            72     72      72        72
# sadness             223         223           223    223     223       223
# violence            165         165           165    165     165       165
# world/life          273         273           273    273     273       273
#
#             world/life  night/time  romantic  obscene  sadness
# topic
# music              129         129       129      129      129
# night/time          82          82        82       82       82
# obscene             79          79        79       79       79
# romantic            72          72        72       72       72
# sadness            223         223       223      223      223
# violence           165         165       165      165      165
# world/life         273         273       273      273      273

# %%
count_70s_pop = [129, 82, 79, 72, 223, 165, 273]
fig_70s_pop, ax_70s_pop = plt.subplots()

ax_70s_pop.pie(count_70s_pop, labels= labels, autopct="%1.1f%%")

ax_70s_pop.axis('equal')

plt.title('Topics of Pop Songs in 1970s')

plt.style.use('dark_background')

plt.legend(labels, bbox_to_anchor=(1,1), loc='best')

plt.show()

# %%
music_topics_eighties.groupby(by="topic").count()
# Out:
#             artist_name  track_name  release_date  genre  lyrics  violence  \
# topic
# music               338         338           338    338     338       338
# night/time          344         344           344    344     344       344
# obscene             595         595           595    595     595       595
# romantic            222         222           222    222     222       222
# sadness            1138        1138          1138   1138    1138      1138
# violence           1052        1052          1052   1052    1052      1052
# world/life          892         892           892    892     892       892
#
#             world/life  night/time  romantic  obscene  sadness
# topic
# music              338         338       338      338      338
# night/time         344         344       344      344      344
# obscene            595         595       595      595      595
# romantic           222         222       222      222      222
# sadness           1138        1138      1138     1138     1138
# violence          1052        1052      1052     1052     1052
# world/life         892         892       892      892      892

# %%
eighties_count = [338, 344, 595, 222, 1138, 1052, 892]
fig_80s, ax_80s = plt.subplots()

ax_80s.pie(eighties_count, labels= labels, autopct="%1.1f%%")

ax_80s.axis('equal')

plt.title('Topics of Songs in 1980s')

plt.style.use('dark_background')

plt.legend(labels, bbox_to_anchor=(1,1), loc='best')

plt.show()

# %%
music_topics_80s_pop.groupby(by="topic").count()
# Out:
#             artist_name  track_name  release_date  genre  lyrics  violence  \
# topic
# music                73          73            73     73      73        73
# night/time           96          96            96     96      96        96
# obscene              95          95            95     95      95        95
# romantic             61          61            61     61      61        61
# sadness             296         296           296    296     296       296
# violence            284         284           284    284     284       284
# world/life          260         260           260    260     260       260
#
#             world/life  night/time  romantic  obscene  sadness
# topic
# music               73          73        73       73       73
# night/time          96          96        96       96       96
# obscene             95          95        95       95       95
# romantic            61          61        61       61       61
# sadness            296         296       296      296      296
# violence           284         284       284      284      284
# world/life         260         260       260      260      260

# %%
count_80s_pop = [73, 96, 95, 61, 296, 284, 260]
fig_80s_pop, ax_80s_pop = plt.subplots()

ax_80s_pop.pie(count_80s_pop, labels= labels, autopct="%1.1f%%")

ax_80s_pop.axis('equal')

plt.title('Topics of Pop Songs in 1980s')

plt.style.use('dark_background')

plt.legend(labels, bbox_to_anchor=(1,1), loc='best')

plt.show()

# %%
music_topics_nineties.groupby(by="topic").count()
# Out:
#             artist_name  track_name  release_date  genre  lyrics  violence  \
# topic
# music               308         308           308    308     308       308
# night/time          237         237           237    237     237       237
# obscene             763         763           763    763     763       763
# romantic            188         188           188    188     188       188
# sadness            1005        1005          1005   1005    1005      1005
# violence            979         979           979    979     979       979
# world/life          892         892           892    892     892       892
#
#             world/life  night/time  romantic  obscene  sadness
# topic
# music              308         308       308      308      308
# night/time         237         237       237      237      237
# obscene            763         763       763      763      763
# romantic           188         188       188      188      188
# sadness           1005        1005      1005     1005     1005
# violence           979         979       979      979      979
# world/life         892         892       892      892      892

# %%
nineties_count = [308, 237, 763, 188, 1005, 979, 892]
fig_90s, ax_90s = plt.subplots()

ax_90s.pie(nineties_count, labels= labels, autopct="%1.1f%%")

ax_90s.axis('equal')

plt.title('Topics of Songs in 1990s')

plt.style.use('dark_background')

plt.legend(labels, bbox_to_anchor=(1,1), loc='best')

plt.show()

# %%
music_topics_90s_pop.groupby(by="topic").count()
# Out:
#             artist_name  track_name  release_date  genre  lyrics  violence  \
# topic
# music                48          48            48     48      48        48
# night/time           61          61            61     61      61        61
# obscene             186         186           186    186     186       186
# romantic             51          51            51     51      51        51
# sadness             271         271           271    271     271       271
# violence            201         201           201    201     201       201
# world/life          238         238           238    238     238       238
#
#             world/life  night/time  romantic  obscene  sadness
# topic
# music               48          48        48       48       48
# night/time          61          61        61       61       61
# obscene            186         186       186      186      186
# romantic            51          51        51       51       51
# sadness            271         271       271      271      271
# violence           201         201       201      201      201
# world/life         238         238       238      238      238

# %%
count_90s_pop = [48, 61, 186, 51, 271, 201, 238]
fig_90s_pop, ax_90s_pop = plt.subplots()

ax_90s_pop.pie(count_90s_pop, labels= labels, autopct="%1.1f%%")

ax_90s_pop.axis('equal')

plt.title('Topics of Pop Songs in 1990s')

plt.style.use('dark_background')

plt.legend(labels, bbox_to_anchor=(1,1), loc='best')

plt.show()

# %%
music_topics_2000s.groupby(by="topic").count()
# Out:
#             artist_name  track_name  release_date  genre  lyrics  violence  \
# topic
# music               293         293           293    293     293       293
# night/time          277         277           277    277     277       277
# obscene             963         963           963    963     963       963
# romantic            168         168           168    168     168       168
# sadness             944         944           944    944     944       944
# violence           1116        1116          1116   1116    1116      1116
# world/life          917         917           917    917     917       917
#
#             world/life  night/time  romantic  obscene  sadness
# topic
# music              293         293       293      293      293
# night/time         277         277       277      277      277
# obscene            963         963       963      963      963
# romantic           168         168       168      168      168
# sadness            944         944       944      944      944
# violence          1116        1116      1116     1116     1116
# world/life         917         917       917      917      917

# %%
count_2000s = [293, 277, 963, 168, 944, 1116, 917]
fig_00s, ax_00s = plt.subplots()

ax_00s.pie(count_2000s, labels= labels, autopct="%1.1f%%")

ax_00s.axis('equal')

plt.title('Topics of Songs in 2000s')

plt.style.use('dark_background')

plt.legend(labels, bbox_to_anchor=(1,1), loc='best')

plt.show()

# %%
music_topics_00s_pop.groupby(by="topic").count()
# Out:
#             artist_name  track_name  release_date  genre  lyrics  violence  \
# topic
# music                42          42            42     42      42        42
# night/time           67          67            67     67      67        67
# obscene             254         254           254    254     254       254
# romantic             25          25            25     25      25        25
# sadness             268         268           268    268     268       268
# violence            243         243           243    243     243       243
# world/life          199         199           199    199     199       199
#
#             world/life  night/time  romantic  obscene  sadness
# topic
# music               42          42        42       42       42
# night/time          67          67        67       67       67
# obscene            254         254       254      254      254
# romantic            25          25        25       25       25
# sadness            268         268       268      268      268
# violence           243         243       243      243      243
# world/life         199         199       199      199      199

# %%
count_00s_pop = [42, 67, 254, 25, 268, 243, 199]
fig_00s_pop, ax_00s_pop = plt.subplots()

ax_00s_pop.pie(count_00s_pop, labels= labels, autopct="%1.1f%%")

ax_00s_pop.axis('equal')

plt.title('Topics of Pop Songs in 2000s')

plt.style.use('dark_background')

plt.legend(labels, bbox_to_anchor=(1,1), loc='best')

plt.show()

# %%
music_topics_2010s.groupby(by="topic").count()
# Out:
#             artist_name  track_name  release_date  genre  lyrics  violence  \
# topic
# music               243         243           243    243     243       243
# night/time          319         319           319    319     319       319
# obscene            1679        1679          1679   1679    1679      1679
# romantic            119         119           119    119     119       119
# sadness             993         993           993    993     993       993
# violence           1336        1336          1336   1336    1336      1336
# world/life          847         847           847    847     847       847
#
#             world/life  night/time  romantic  obscene  sadness
# topic
# music              243         243       243      243      243
# night/time         319         319       319      319      319
# obscene           1679        1679      1679     1679     1679
# romantic           119         119       119      119      119
# sadness            993         993       993      993      993
# violence          1336        1336      1336     1336     1336
# world/life         847         847       847      847      847

# %%
count_2010s = [431, 245, 317, 351, 898, 390, 692]
fig_10s, ax_10s = plt.subplots()

ax_10s.pie(count_2010s, labels= labels, autopct="%1.1f%%")

ax_10s.axis('equal')

plt.title('Topics of Songs in 2010s')

plt.style.use('dark_background')

plt.legend(labels, bbox_to_anchor=(1,1), loc='best')

plt.show()

# %%
music_topics_10s_pop.groupby(by="topic").count()
# Out:
#             artist_name  track_name  release_date  genre  lyrics  violence  \
# topic
# music                36          36            36     36      36        36
# night/time           60          60            60     60      60        60
# obscene             495         495           495    495     495       495
# romantic             27          27            27     27      27        27
# sadness             224         224           224    224     224       224
# violence            202         202           202    202     202       202
# world/life          120         120           120    120     120       120
#
#             world/life  night/time  romantic  obscene  sadness
# topic
# music               36          36        36       36       36
# night/time          60          60        60       60       60
# obscene            495         495       495      495      495
# romantic            27          27        27       27       27
# sadness            224         224       224      224      224
# violence           202         202       202      202      202
# world/life         120         120       120      120      120

# %%
count_10s_pop = [36, 60, 495, 27, 224, 202, 120]
fig_10s_pop, ax_10s_pop = plt.subplots()

ax_10s_pop.pie(count_10s_pop, labels= labels, autopct="%1.1f%%")

ax_10s_pop.axis('equal')

plt.title('Topics of Pop Songs in 2010s')

plt.style.use('dark_background')

plt.legend(labels, bbox_to_anchor=(1,1), loc='best')

plt.show()
